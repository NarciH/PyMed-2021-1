# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('./data/ramen_score.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2584 entries, 0 to 2583
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2584 non-null   object
#  1   Brand     2566 non-null   object
#  2   Variety   2566 non-null   object
#  3   Style     2564 non-null   object
#  4   Country   2566 non-null   object
#  5   Stars     2566 non-null   object
#  6   Top Ten   37 non-null     object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %%
df_new = df[~df.Brand.isna()].fillna(-1)
df_new.to_csv('./data/rament_db.csv',sep = ',',index = False)

# %%
df_new
# Out:
#      Review #           Brand  \
# 0        2580       New Touch
# 1        2579        Just Way
# 2        2578          Nissin
# 3        2577         Wei Lih
# 4        2576  Ching's Secret
# ...       ...             ...
# 2578        6           Vifon
# 2580        4         Wai Wai
# 2581        3         Wai Wai
# 2582        2         Wai Wai
# 2583        1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %% [markdown]
# - ¿Cuáles son los restaurantes que están en el top 10?
# - ¿Cuántos restaurantes hay por País?
# - ¿Cuántas variedades de restaurantes hay?
# - ¿Cuántos restaurantes existen por variedad?
# - ¿Cuántos restaurantes existen por país y variedad?
#
# - ¿Cuál es el promedio y la desviación estandar de la calificación de los resturantes por país, por estilo, por variedad?
# - ¿Cómo es la distribución de la calificación por país, y por estilo?
